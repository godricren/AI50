# %% [markdown]
# ## 聚类算法

# %%
from sklearn.datasets import make_blobs
from matplotlib import pyplot as plt

# 生成模拟数据
X, y = make_blobs(n_samples=2000, n_features=2, centers=5, random_state=42)

#画图看一下
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5)

# %%
kmeans.fit(X)
# Out:
# KMeans(n_clusters=5)

# %%
kmeans.cluster_centers_
# Out:
# array([[-8.85754411,  7.33176566],
#        [ 2.01553054,  4.17573025],
#        [-6.92958209, -6.79739545],
#        [-2.52846663,  9.01204984],
#        [ 4.74508669,  2.03852592]])

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s=200,color='red')
